# %% [markdown]
# # PRAKTIKUM BIG DATA ANALYTICS - PERTEMUAN 6 (EXPORTING IMPORTING DATA))
#
# ### TUJUAN:
# Mampu melakukan Extract, Transform dan Load dari dokumen CSV dan Excel ke dalam MySQL.

# %% [markdown]
# ## PRAKTIK

# %% [markdown]
# ### 1. Download file data-pert11.zip yang berisi pegawai_cab01.csv dan pegawai_cab02.xlsx
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Masuklah ke Database MySQL di komputer anda (anda dapat menggunakan phpMyAdmin), kemudian buatlah database baru bernama bigdata6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Skenario untuk praktik ini:
# terdapat 2 buah dokumen dengan jenis berbeda yaitu pegawai_cab01.csv berupa file CSV dan pegawai_cab02.xlsx berupa file Excell.
#
# - file pegawai_cab01.csv terdiri dari: nik,nama,gaji,tglmasuk,job_id,job_title
#
# - file pegawai_cab02.xlsx terdiri dari: nik,nama,job,status.
#
# Status berisi tulisan “OUT” jika pegawai tersebut sudah keluar. Goalnya adalah, menggabungkan isi file `pegawai_cab01.csv` dan `pegawai_cab02.xlsx` untuk field `nik`, `nama`, `job_id` ke tabel `pegawai`, sedangkan `job_id` dan `job_title` akan masuk ke tabel `Job`.

# %% [markdown]
# ### 4. Langkah awal buatlah file etl-1.py, untuk mengakses data CSV nya. Ketikkan script berikut ini:

# %%
import pandas as pd

#baca file csv
df_csv = pd.read_csv("pegawai_cab01.csv")

df_csv_filter = df_csv[['nik','nama','job_id']]
print(df_csv_filter)
# Out:
#      nik             nama      job_id
# 0    206    William Gietz  AC_ACCOUNT
# 1    205  Shelley Higgins      AC_MGR
# 2    200  Jennifer Whalen     AD_ASST
# 3    100      Steven King     AD_PRES
# 4    101    Neena Kochhar       AD_VP
# ..   ...              ...         ...
# 102  120    Matthew Weiss      ST_MAN
# 103  121       Adam Fripp      ST_MAN
# 104  122   Payam Kaufling      ST_MAN
# 105  123   Shanta Vollman      ST_MAN
# 106  124    Kevin Mourgos      ST_MAN
#
# [107 rows x 3 columns]

# %% [markdown]
# kita hanya mengambil data yang berada di kolom `nik`, `nama`, dan `job_id`. Hal itu bisa kita lakukan dengan menggunakan fungsi filter yang kita tulisakan dengan baris kode `df_csv_filter = df_csv[['nik','nama','job_id']]`. Terakhir, kita cetak value yang ada di variabel `df_csv_filter` dengan kode `print(df_csv_filter)`.

# %% [markdown]
# _**Langkah selanjutnya ada di file etl-2.ipynb**_
